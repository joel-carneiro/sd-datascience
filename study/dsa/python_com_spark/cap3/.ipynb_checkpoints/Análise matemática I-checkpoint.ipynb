# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
import sympy as smp
# %matplotlib inline

# %%
def is_prime(number):
    predecessors = np.arange(2, number, 1)
    return not np.any((number % predecessors) == 0)

# %%
df = pd.DataFrame({'index': np.arange(1000), 'number' : np.arange(1000)})

# %%
df['square'] = df['number'] ** 2
df['cubic'] = df['number'] ** 3
df['diff_square'] = df['square'].diff()
df['diff_cubic'] = df['cubic'].diff()
df['is_prime'] = df['number'].apply(is_prime)

# %%
df
# Out:
#      index  number  square      cubic  diff_square  diff_cubic  is_prime
# 0        0       0       0          0          NaN         NaN      True
# 1        1       1       1          1          1.0         1.0      True
# 2        2       2       4          8          3.0         7.0      True
# 3        3       3       9         27          5.0        19.0      True
# 4        4       4      16         64          7.0        37.0     False
# ..     ...     ...     ...        ...          ...         ...       ...
# 995    995     995  990025  985074875       1989.0   2967091.0     False
# 996    996     996  992016  988047936       1991.0   2973061.0     False
# 997    997     997  994009  991026973       1993.0   2979037.0      True
# 998    998     998  996004  994011992       1995.0   2985019.0     False
# 999    999     999  998001  997002999       1997.0   2991007.0     False
#
# [1000 rows x 7 columns]

# %%
x = smp.Symbol('x')

f = x ** 2

f
# Out:
# x**2

# %%
smp.diff(f)
# Out:
# 2*x

# %%
sns.lineplot(x='number', y='diff_square', data=df)
# Out:
# <AxesSubplot: xlabel='number', ylabel='diff_square'>

# %%
g = x ** 3
g
# Out:
# x**3

# %%
smp.diff(g)
# Out:
# 3*x**2

# %%
sns.lineplot(x='number', y='diff_cubic', data=df)
# Out:
# <AxesSubplot: xlabel='number', ylabel='diff_cubic'>

# %%
primes = df.query('is_prime == True')

# %%
primes['index'] = np.arange(len(primes))
# Out:
# /tmp/ipykernel_6155/493088484.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   primes['index'] = np.arange(len(primes))

# %%
primes
# Out:
#      index  number  square      cubic  diff_square  diff_cubic  is_prime  \
# 0        0       0       0          0          NaN         NaN      True
# 1        1       1       1          1          1.0         1.0      True
# 2        2       2       4          8          3.0         7.0      True
# 3        3       3       9         27          5.0        19.0      True
# 5        4       5      25        125          9.0        61.0      True
# ..     ...     ...     ...        ...          ...         ...       ...
# 971    165     971  942841  915498611       1941.0   2825611.0      True
# 977    166     977  954529  932574833       1953.0   2860657.0      True
# 983    167     983  966289  949862087       1965.0   2895919.0      True
# 991    168     991  982081  973242271       1981.0   2943271.0      True
# 997    169     997  994009  991026973       1993.0   2979037.0      True
#
#      diff_prime
# 0           NaN
# 1           1.0
# 2           1.0
# 3           1.0
# ...

# %%
primes['diff_prime'] = primes['number'].diff()
# Out:
# /tmp/ipykernel_6155/3254020739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   primes['diff_prime'] = primes['number'].diff()

# %%
ax = sns.lineplot(x='index', y='diff_prime', data=primes)

ax.figure.set_size_inches(10, 5)

# %%
h = smp.diff(f)
