# %% [markdown]
# <font color='green' size=6> HBO Max TV Shows and Movies </font>
#
# ---

# %% [markdown]
# # 1 - Definição do Problema

# %% [markdown]
# Analisar os dados da base de dados da HBO Max, afim de gerar um modelo capaz de recomendar filmes para usuários que tenham o gosto parecido. Além de gerar análise de shows, popularidade e afins

# %% [markdown]
# # 2 - Coleta de Dados

# %%
# Importando módulos inicialmente necessários
import pandas as pd
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importando a base de dados para um objeto dataframe
credits = pd.read_csv('data/credits.csv')
titles = pd.read_csv('data/titles.csv')

# %%
# Visualizando as 3 primeiras observações da base de dados "credits"
credits.head(3)
# Out:
#    person_id        id          name          character   role
# 0      60017  tm155702  Judy Garland       Dorothy Gale  ACTOR
# 1      53496  tm155702    Ray Bolger   Hunk / Scarecrow  ACTOR
# 2      79549  tm155702    Jack Haley  Hickory / Tin Man  ACTOR

# %%
# Visualizando as 3 primeiras observações da base de dados "titles"
titles.head(3)
# Out:
#          id             title   type  \
# 0  tm155702  The Wizard of Oz  MOVIE
# 1   tm83648      Citizen Kane  MOVIE
# 2   tm77588        Casablanca  MOVIE
#
#                                          description  release_year  \
# 0  Young Dorothy finds herself in a magical world...          1939
# 1  Newspaper magnate, Charles Foster Kane is take...          1941
# 2  In Casablanca, Morocco in December 1941, a cyn...          1942
#
#   age_certification  runtime                       genres  \
# 0                 G      102        ['fantasy', 'family']
# 1                PG      119                    ['drama']
# 2                PG      102  ['drama', 'romance', 'war']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      NaN  tt0032138         8.1    389774.0
# 1               ['US']      NaN  tt0033467         8.3    433804.0
# 2               ['US']      NaN  tt0034583         8.5    558849.0
#
#    tmdb_popularity  tmdb_score
# 0           41.442         7.6
# 1           14.383         8.0
# 2           20.087         8.2

# %% [markdown]
# # 3 - Limpeza e Preparação de Dados

# %% [markdown]
# ## 3.1 - Dados Dos Atores

# %%
# Dimensão da base de dados
credits.shape
# Out:
# (66393, 5)

# %%
# Visualização mais abrangente da base de dados
credits.head(10)
# Out:
#    person_id        id               name  \
# 0      60017  tm155702       Judy Garland
# 1      53496  tm155702         Ray Bolger
# 2      79549  tm155702         Jack Haley
# 3      79548  tm155702          Bert Lahr
# 4      60995  tm155702  Margaret Hamilton
# 5      53493  tm155702       Frank Morgan
# 6      79551  tm155702     Clara Blandick
# 7      41661  tm155702   Charley Grapewin
# 8      72816  tm155702       Billie Burke
# 9      79553  tm155702         Pat Walshe
#
#                                  character   role
# 0                             Dorothy Gale  ACTOR
# 1                         Hunk / Scarecrow  ACTOR
# 2                        Hickory / Tin Man  ACTOR
# 3                     Zeke / Cowardly Lion  ACTOR
# 4  Elmira Gulch / Wicked Witch of the West  ACTOR
# 5          Professor Marvel / Wizard of Oz  ACTOR
# 6                                Auntie Em  ACTOR
# 7                              Uncle Henry  ACTOR
# 8                                   Glinda  ACTOR
# 9                                    Nikko  ACTOR

# %%
# Visualização do sumário da base de dados
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66393 entries, 0 to 66392
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  66393 non-null  int64
#  1   id         66393 non-null  object
#  2   name       66393 non-null  object
#  3   character  61888 non-null  object
#  4   role       66393 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.5+ MB

# %%
# Observando se há dados nulos
credits.isna().sum()
# Out:
# person_id       0
# id              0
# name            0
# character    4505
# role            0
# dtype: int64

# %%
# Excluindo dados nulos
credits.dropna(inplace=True)

# %% [markdown]
# ## 3.2 - Limpeza de Dados dos Filmes

# %%
# Visualizando a base de dados
titles.head(3)
# Out:
#          id             title   type  \
# 0  tm155702  The Wizard of Oz  MOVIE
# 1   tm83648      Citizen Kane  MOVIE
# 2   tm77588        Casablanca  MOVIE
#
#                                          description  release_year  \
# 0  Young Dorothy finds herself in a magical world...          1939
# 1  Newspaper magnate, Charles Foster Kane is take...          1941
# 2  In Casablanca, Morocco in December 1941, a cyn...          1942
#
#   age_certification  runtime                       genres  \
# 0                 G      102        ['fantasy', 'family']
# 1                PG      119                    ['drama']
# 2                PG      102  ['drama', 'romance', 'war']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      NaN  tt0032138         8.1    389774.0
# 1               ['US']      NaN  tt0033467         8.3    433804.0
# 2               ['US']      NaN  tt0034583         8.5    558849.0
#
#    tmdb_popularity  tmdb_score
# 0           41.442         7.6
# 1           14.383         8.0
# 2           20.087         8.2

# %%
# Visualizando um sumário da base de dados
titles.describe()
# Out:
#        release_year      runtime     seasons   imdb_score    imdb_votes  \
# count   3294.000000  3294.000000  756.000000  2922.000000  2.911000e+03
# mean    2001.194293    80.914997    2.998677     6.883949  6.461835e+04
# std       23.542337    38.475347    3.651181     1.059668  1.754617e+05
# min     1901.000000     1.000000    1.000000     1.500000  5.000000e+00
# 25%     1995.000000    51.250000    1.000000     6.300000  9.245000e+02
# 50%     2010.000000    89.000000    2.000000     7.000000  8.071000e+03
# 75%     2018.000000   106.000000    4.000000     7.600000  4.764500e+04
# max     2022.000000   255.000000   52.000000     9.400000  2.555504e+06
#
#        tmdb_popularity   tmdb_score
# count      3261.000000  3026.000000
# mean         21.105891     6.850099
# std          89.137800     1.081377
# min           0.050393     1.000000
# 25%           3.450000     6.200000
# 50%           8.561000     6.900000
# 75%          17.711000     7.500000
# max        4447.894000    10.000000

# %%
# Visualizando informações da base de dados
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3294 entries, 0 to 3293
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3294 non-null   object
#  1   title                 3294 non-null   object
#  2   type                  3294 non-null   object
#  3   description           3282 non-null   object
#  4   release_year          3294 non-null   int64
#  5   age_certification     2086 non-null   object
#  6   runtime               3294 non-null   int64
#  7   genres                3294 non-null   object
#  8   production_countries  3294 non-null   object
#  9   seasons               756 non-null    float64
#  10  imdb_id               2968 non-null   object
#  11  imdb_score            2922 non-null   float64
#  12  imdb_votes            2911 non-null   float64
#  13  tmdb_popularity       3261 non-null   float64
#  14  tmdb_score            3026 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 386.1+ KB

# %%
# Proporção de dados nulos
titles.isna().sum() / len(titles)
# Out:
# id                      0.000000
# title                   0.000000
# type                    0.000000
# description             0.003643
# release_year            0.000000
# age_certification       0.366727
# runtime                 0.000000
# genres                  0.000000
# production_countries    0.000000
# seasons                 0.770492
# imdb_id                 0.098968
# imdb_score              0.112933
# imdb_votes              0.116272
# tmdb_popularity         0.010018
# tmdb_score              0.081360
# dtype: float64

# %%
# Excluindo colunas que não serão usadas
titles.drop(columns=['seasons', 'description'], inplace=True)

# %%
# Limpando a coluna de certificação de idade
titles['age_certification'] = titles['age_certification'].fillna('G')

# %%
# Limpando o resto da base de dados
titles.fillna(0, inplace=True)

# %%
# Visualizando todos os genêros incluidos
genres = set()
for lg in titles['genres']:
    genres.update(eval(lg))

# %%
# Adicionando novas colunas a base de dados
for gen in genres:
    titles[gen] = titles['genres'].apply(lambda x : gen in eval(x))
titles.drop(columns=['genres'], inplace=True)

# %%
# Visualizando todos os países incluidos
countries = set()
for lc in titles['production_countries']:
    countries.update(eval(lc))

# %%
# Adicionando novas colunas a base de dados
for country in countries:
    titles[country] = titles['production_countries'].apply(lambda x : country in eval(x))
titles.drop(columns=['production_countries'], inplace=True)

# %%
# Alterando valores booleanos para valores númerios
titles.replace({True: 1, False : 0}, inplace=True)

# %% [markdown]
# # 4 - Análise Exploratória de Dados

# %% [markdown]
# ## 4.1 - Análise da Base de Créditos

# %%
# Dimensão da base de dados
credits.shape
# Out:
# (61888, 5)

# %%
# Separando dados segundo os nomes
names = pd.value_counts(credits['name'])

# %%
# Escolhendo os 15 atores que mais apareceram
names = names.sort_values(ascending=False)[:15]

# %%
# Visualizando os atores que mais apareceram nos filmes/shows da HBO Max
plt.style.use('ggplot')
axes = sns.barplot(x=names.values, y=names.index, palette='mako')
axes.figure.set_size_inches(10, 5)
axes.set_title('Total de aparições de atores na HBO Max', fontsize=14)
axes.set_xlabel('Contagem')
# Out:
# Text(0.5, 0, 'Contagem')

# %% [markdown]
# ## 4.2 - Análise da Base de Títulos

# %%
# Diferença de dados de filme de classificação de idade
_ = pd.value_counts(titles['age_certification'])
sns.barplot(x=_.index, y=_.values)
# Out:
# <Axes: >

# %%
# O total de votos na HBO por classificação de idade
_ = titles.groupby(by='age_certification')['imdb_votes'].mean()
_ = _.sort_values(ascending=False)
sns.barplot(x=_.index, y=_.values)
# Out:
# <Axes: xlabel='age_certification'>

# %%
# A média de nota bruta por classificação de idade
_ = titles.groupby(by='age_certification')['imdb_score'].mean()
_ = _.sort_values(ascending=False)
sns.barplot(x=_.index, y=_.values)
# Out:
# <Axes: xlabel='age_certification'>

# %%
movies = titles.query('type == "MOVIE"')
shows = titles.query('type == "SHOW"')

# %%
# Os 10 programas melhores avaliados da HBO Max
titles.query('imdb_votes > 284').sort_values(by='imdb_score', ascending=False).iloc[:10, :10]
# Out:
#             id                             title   type  release_year  \
# 1038   ts17149                  Band of Brothers   SHOW          2001
# 2531   ts88632                         Chernobyl   SHOW          2019
# 1030   ts22047                          The Wire   SHOW          2002
# 725   tm119206          The Shawshank Redemption  MOVIE          1994
# 1878   ts20233                    Rick and Morty   SHOW          2013
# 669    ts16786                 Eyes on the Prize   SHOW          1987
# 712    ts20995                      The Sopranos   SHOW          1999
# 1706       ts2                   Game of Thrones   SHOW          2011
# 1042   ts21482  Fullmetal Alchemist: Brotherhood   SHOW          2009
# 2740   ts89481              The World Between Us   SHOW          2019
#
#      age_certification  runtime     imdb_id  imdb_score  imdb_votes  \
# 1038             TV-MA       59   tt0185906         9.4    440706.0
# 2531             TV-MA       65   tt7366338         9.4    693955.0
# 1030             TV-MA       59   tt0306414         9.3    325150.0
# 725                  R      142   tt0111161         9.3   2548100.0
# 1878             TV-MA       22   tt2861424         9.2    473951.0
# 669              TV-PG       57   tt0092999         9.2       656.0
# 712              TV-MA       55   tt0141842         9.2    372367.0
# 1706             TV-MA       58   tt0944947         9.2   1983794.0
# 1042             TV-14       29   tt1355642         9.1    156503.0
# 2740                 G       28  tt10073114         9.0      2333.0
#
#       tmdb_popularity
# 1038           62.034
# 2531           64.507
# 1030           36.030
# 725            66.224
# 1878          238.434
# 669             1.770
# 712           151.628
# 1706          492.101
# 1042          110.534
# 2740            4.244

# %%
# Os 10 filmes mais avaliados
movies.query('imdb_votes > 284').sort_values(by='imdb_score', ascending=False).iloc[:10, :10]
# Out:
#             id                                              title   type  \
# 725   tm119206                           The Shawshank Redemption  MOVIE
# 1209  tm142381      The Lord of the Rings: The Return of the King  MOVIE
# 1035   tm56184                                    The Dark Knight  MOVIE
# 1051   tm92641                                          Inception  MOVIE
# 1151  tm115982              The Lord of the Rings: The Two Towers  MOVIE
# 1033   tm44313  The Lord of the Rings: The Fellowship of the Ring  MOVIE
# 899    tm24890                Dave Chappelle: Killin' Them Softly  MOVIE
# 531   tm155787                                         GoodFellas  MOVIE
# 201   tm127410                    One Flew Over the Cuckoo's Nest  MOVIE
# 732       tm10                                         The Matrix  MOVIE
#
#       release_year age_certification  runtime    imdb_id  imdb_score  \
# 725           1994                 R      142  tt0111161         9.3
# 1209          2003             PG-13      201  tt0167260         9.0
# 1035          2008             PG-13      152  tt0468569         9.0
# 1051          2010             PG-13      148  tt1375666         8.8
# 1151          2002             PG-13      223  tt0167261         8.8
# 1033          2001             PG-13      179  tt0120737         8.8
# 899           2000                 G       57  tt0251654         8.8
# 531           1990                 R      146  tt0099685         8.7
# 201           1975                 R      133  tt0073486         8.7
# 732           1999                 R      136  tt0133093         8.7
#
#       imdb_votes  tmdb_popularity
# 725    2548100.0           66.224
# 1209   1776725.0           96.115
# 1035   2555504.0          102.667
# 1051   2268288.0          109.090
# 1151   1604677.0          109.721
# 1033   1798012.0           94.640
# 899       9877.0            5.792
# 531    1113695.0           31.153
# 201     981994.0           24.317
# 732    1857949.0           71.482

# %%
# Os 10 shows mais avaliados
shows.query('imdb_votes > 284').sort_values(by='imdb_score', ascending=False).iloc[:10, :10]
# Out:
#            id                             title  type  release_year  \
# 1038  ts17149                  Band of Brothers  SHOW          2001
# 2531  ts88632                         Chernobyl  SHOW          2019
# 1030  ts22047                          The Wire  SHOW          2002
# 1706      ts2                   Game of Thrones  SHOW          2011
# 1878  ts20233                    Rick and Morty  SHOW          2013
# 712   ts20995                      The Sopranos  SHOW          1999
# 669   ts16786                 Eyes on the Prize  SHOW          1987
# 1042  ts21482  Fullmetal Alchemist: Brotherhood  SHOW          2009
# 1075  ts11313                        DEATH NOTE  SHOW          2006
# 2740  ts89481              The World Between Us  SHOW          2019
#
#      age_certification  runtime     imdb_id  imdb_score  imdb_votes  \
# 1038             TV-MA       59   tt0185906         9.4    440706.0
# 2531             TV-MA       65   tt7366338         9.4    693955.0
# 1030             TV-MA       59   tt0306414         9.3    325150.0
# 1706             TV-MA       58   tt0944947         9.2   1983794.0
# 1878             TV-MA       22   tt2861424         9.2    473951.0
# 712              TV-MA       55   tt0141842         9.2    372367.0
# 669              TV-PG       57   tt0092999         9.2       656.0
# 1042             TV-14       29   tt1355642         9.1    156503.0
# 1075             TV-14       24   tt0877057         9.0    302147.0
# 2740                 G       28  tt10073114         9.0      2333.0
#
#       tmdb_popularity
# 1038           62.034
# 2531           64.507
# 1030           36.030
# 1706          492.101
# 1878          238.434
# 712           151.628
# 669             1.770
# 1042          110.534
# 1075          104.037
# 2740            4.244

# %%
# Método inicial de recomendação de filmes por gênero
def recommend_by_genre(gender, number):
    recommend_titles = titles[titles[gender] == 1]
    recommend_titles = recommend_titles.query('imdb_votes > 248')
    recommend_titles = recommend_titles.sort_values(by='imdb_score', ascending=False)
    return recommend_titles.iloc[:number, :10]

# %%
recommend_by_genre('fantasy', 10)
# Out:
#             id                                              title   type  \
# 1706       ts2                                    Game of Thrones   SHOW
# 1042   ts21482                   Fullmetal Alchemist: Brotherhood   SHOW
# 1075   ts11313                                         DEATH NOTE   SHOW
# 1209  tm142381      The Lord of the Rings: The Return of the King  MOVIE
# 1720   ts32835                                    Hunter x Hunter   SHOW
# 1890   ts20079                               Over the Garden Wall   SHOW
# 1151  tm115982              The Lord of the Rings: The Two Towers  MOVIE
# 1033   tm44313  The Lord of the Rings: The Fellowship of the Ring  MOVIE
# 2646  ts229283                      Adventure Time: Distant Lands   SHOW
# 1264   ts85715                           Justice League Unlimited   SHOW
#
#       release_year age_certification  runtime     imdb_id  imdb_score  \
# 1706          2011             TV-MA       58   tt0944947         9.2
# 1042          2009             TV-14       29   tt1355642         9.1
# 1075          2006             TV-14       24   tt0877057         9.0
# 1209          2003             PG-13      201   tt0167260         9.0
# 1720          2011             TV-14       23   tt2098220         9.0
# 1890          2014             TV-PG       11   tt3718778         8.8
# 1151          2002             PG-13      223   tt0167261         8.8
# 1033          2001             PG-13      179   tt0120737         8.8
# 2646          2020             TV-PG       45  tt11165358         8.7
# 1264          2004             TV-Y7       24   tt6025022         8.7
#
#       imdb_votes  tmdb_popularity
# 1706   1983794.0          492.101
# 1042    156503.0          110.534
# 1075    302147.0          104.037
# 1209   1776725.0           96.115
# 1720     87857.0          117.924
# 1890     51729.0           39.166
# 1151   1604677.0          109.721
# 1033   1798012.0           94.640
# 2646      4047.0           73.100
# 1264     15112.0           46.703

# %% [markdown]
# # 5 - Criação do Modelo

# %%
# Definindo as variáveis binárias dos gêneros
genres = titles.iloc[:, 11:30]

# %%
# Criação e treino do modelo
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, n_init=10)

kmeans.fit(genres)
# Out:
# KMeans(n_clusters=5, n_init=10)

# %%
# Definindo a variável target na base de dados
genres['target'] = kmeans.labels_

# %%
# Salvando o arquivo em formato csv
genres.to_csv('data/genres.csv', index=False)

# %% [markdown]
# # 6 - Deploy Do Modelo

# %%
with open('models/hbomax_model.pickle', 'wb') as f:
    pickle.dump(kmeans, f)
