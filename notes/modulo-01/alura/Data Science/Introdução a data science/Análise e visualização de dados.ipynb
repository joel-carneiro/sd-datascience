# %% [markdown]
# # Introdução 1.0

# %%
import pandas as pd

# %%
notas = pd.read_csv('data/ratings.csv')
notas.columns = ['usuario', 'filme_id', 'nota', 'momento']
notas.head()
# Out:
#    usuario  filme_id  nota    momento
# 0        1         1   4.0  964982703
# 1        1         3   4.0  964981247
# 2        1         6   4.0  964982224
# 3        1        47   5.0  964983815
# 4        1        50   5.0  964982931

# %%
notas.nota.hist()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.boxplot(x = notas.nota)
# Out:
# <AxesSubplot:xlabel='nota'>

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
nota_media_filme = notas.groupby(by = 'filme_id')['nota'].mean()
nota_media_filme
# Out:
# filme_id
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
nota_media_filme.hist()
# Out:
# <AxesSubplot:>
