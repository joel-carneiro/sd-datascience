# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
dataset = pd.read_csv('/home/jdspy/Documentos/arquivados/datasets/BancoDeDados.csv')

# %%
dataset.head(3)
# Out:
#    amostra                        id_cliente  \
# 0        0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1        1  8912fc0c3bbf1e2fbf35819e21706718
# 2        2  8912fc0c3bbf1e2fbf35819e21706718
#
#                    id_unico_cliente  item_id  cep_cliente cidade_cliente  \
# 0  861eff4711a542e4b93843c6dd7febb0        1        14409         franca
# 1  9eae34bbd3a474ec5d07949ca7de67c0        1        68030       santarem
# 2  9eae34bbd3a474ec5d07949ca7de67c0        2        68030       santarem
#
#   estado_cliente                         id_pedido status_pedido  \
# 0             SP  00e7ee1b050b8499577073aeb2a297a1     delivered
# 1             PA  c1d2b34febe9cd269e378117d6681172     delivered
# 2             PA  c1d2b34febe9cd269e378117d6681172     delivered
#
#         horario_pedido  ... pagamento_sequencial pagamento_tipo  \
# 0  2017-05-16 15:05:35  ...                    1    credit_card
# 1  2017-11-09 00:50:13  ...                    1    credit_card
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116581 entries, 0 to 116580
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   amostra               116581 non-null  int64
#  1   id_cliente            116581 non-null  object
#  2   id_unico_cliente      116581 non-null  object
#  3   item_id               116581 non-null  int64
#  4   cep_cliente           116581 non-null  int64
#  5   cidade_cliente        116581 non-null  object
#  6   estado_cliente        116581 non-null  object
#  7   id_pedido             116581 non-null  object
#  8   status_pedido         116581 non-null  object
#  9   horario_pedido        116581 non-null  object
#  10  pedido_aprovado       116567 non-null  object
#  11  pedido_entregador     115368 non-null  object
#  12  pedido_entregue       114066 non-null  object
#  13  data_estimada         116581 non-null  object
# ...

# %%
def plot_perc(var, dataset):
    plt.figure(figsize=(20, 8))
    
    g = sns.countplot(x = var, data = dataset, orient='h')
    g.set_ylabel('Contagem', fontsize=17)
    
    return g

# %%
plot_perc('estado_vendedor', dataset)
# Out:
# <AxesSubplot:xlabel='estado_vendedor', ylabel='Contagem'>

# %%
plot_perc('estado_cliente', dataset)
# Out:
# <AxesSubplot:xlabel='estado_cliente', ylabel='Contagem'>

# %%
plot_perc('pagamento_tipo', dataset)
# Out:
# <AxesSubplot:xlabel='pagamento_tipo', ylabel='Contagem'>

# %%
dataset_olist = dataset[['id_unico_cliente', 'id_cliente', 'horario_pedido', 'item_id', 'preco']]

dataset_olist.head()
# Out:
#                    id_unico_cliente                        id_cliente  \
# 0  861eff4711a542e4b93843c6dd7febb0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1  9eae34bbd3a474ec5d07949ca7de67c0  8912fc0c3bbf1e2fbf35819e21706718
# 2  9eae34bbd3a474ec5d07949ca7de67c0  8912fc0c3bbf1e2fbf35819e21706718
# 3  3c799d181c34d51f6d44bbbc563024db  f0ac8e5a239118859b1734e1087cbb1f
# 4  23397e992b09769faf5e66f9e171a241  6bc8d08963a135220ed6c6d098831f84
#
#         horario_pedido  item_id   preco
# 0  2017-05-16 15:05:35        1  124.99
# 1  2017-11-09 00:50:13        1  112.99
# 2  2017-11-09 00:50:13        2  112.99
# 3  2017-05-07 20:11:26        1  124.99
# 4  2018-02-03 19:45:40        1  106.99

# %%
dataset_compra = dataset.groupby('id_unico_cliente')['horario_pedido'].max().reset_index()
dataset_compra.columns = ['id_unico_cliente', 'data_max_compra']
dataset_compra['data_max_compra'] = pd.to_datetime(dataset_compra['data_max_compra'])

dataset_compra.head()
# Out:
#                    id_unico_cliente     data_max_compra
# 0  0000366f3b9a7992bf8c76cfdf3221e2 2018-05-10 10:56:27
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f 2018-05-07 11:11:27
# 2  0000f46a3911fa3c0805444483337064 2017-03-10 21:05:03
# 3  0000f6ccb0745a6a4b88665a16c9f078 2017-10-12 20:29:41
# 4  0004aac84e0df4da2b147fca70cf8255 2017-11-14 19:45:42

# %%
dataset_compra['Recencia'] = (dataset_compra['data_max_compra'].max() - dataset_compra['data_max_compra']).dt.days

# %%
dataset_compra
# Out:
#                        id_unico_cliente     data_max_compra  Recencia
# 0      0000366f3b9a7992bf8c76cfdf3221e2 2018-05-10 10:56:27       115
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f 2018-05-07 11:11:27       118
# 2      0000f46a3911fa3c0805444483337064 2017-03-10 21:05:03       541
# 3      0000f6ccb0745a6a4b88665a16c9f078 2017-10-12 20:29:41       325
# 4      0004aac84e0df4da2b147fca70cf8255 2017-11-14 19:45:42       292
# ...                                 ...                 ...       ...
# 94082  fffcf5a5ff07b0908bd4e2dbc735a684 2017-06-08 21:00:36       451
# 94083  fffea47cd6d3cc0a88bd621562a9d061 2017-12-10 20:07:56       266
# 94084  ffff371b4d645b6ecea244b27531430a 2017-02-07 15:49:16       572
# 94085  ffff5962728ec6157033ef9805bacc48 2018-05-02 15:17:41       123
# 94086  ffffd2657e2aad2907e67c3e9daecbeb 2017-05-02 20:18:45       488
#
# [94087 rows x 3 columns]

# %%
dataset_usuario = pd.merge(dataset_olist, dataset_compra[['id_unico_cliente', 'Recencia']], on='id_unico_cliente')

# %%
dataset_usuario
# Out:
#                         id_unico_cliente                        id_cliente  \
# 0       861eff4711a542e4b93843c6dd7febb0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1       9eae34bbd3a474ec5d07949ca7de67c0  8912fc0c3bbf1e2fbf35819e21706718
# 2       9eae34bbd3a474ec5d07949ca7de67c0  8912fc0c3bbf1e2fbf35819e21706718
# 3       3c799d181c34d51f6d44bbbc563024db  f0ac8e5a239118859b1734e1087cbb1f
# 4       23397e992b09769faf5e66f9e171a241  6bc8d08963a135220ed6c6d098831f84
# ...                                  ...                               ...
# 116576  c5da6424f1f5decedef8672a1a0103e1  ce2172509c4149d65212484eb761bc37
# 116577  8d80e477643ec569b24592ce3d9dfc4c  ee1cfdc92e449920e25d3ca4ab4da4f6
# 116578  8d80e477643ec569b24592ce3d9dfc4c  ee1cfdc92e449920e25d3ca4ab4da4f6
# 116579  8c3c961a52bb5a0ffbce1d4e6d25cd67  ab0cf72dfe0538a63a57d6905ccb7b57
# 116580  428f4721a509be8c52de6ec2900ba918  c61336d6c835632048f973d2f2db598d
#
#              horario_pedido  item_id   preco  Recencia
# ...

# %%
from sklearn.cluster import KMeans

def calculate_wcss(data):
    wcss = []
    for k in range(1, 10):
        kmeans = KMeans(n_clusters=k)
        kmeans.fit(x=data)
        data['Clusters'] = kmeans.labels_
        wcss.append(kmeans.inertia_)
    return wcss

# %%
calculate_wcss(dataset_usuario[['Recencia']])
# Out:
# /tmp/ipykernel_6071/1135756456.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Clusters'] = kmeans.labels_
# /tmp/ipykernel_6071/1135756456.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Clusters'] = kmeans.labels_
# /tmp/ipykernel_6071/1135756456.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import warnings

warnings.filterwarnings('ignore')

plt.figure(figsize=(10, 5))

wcss = calculate_wcss(dataset_usuario[['Recencia']])

plt.plot(wcss)
