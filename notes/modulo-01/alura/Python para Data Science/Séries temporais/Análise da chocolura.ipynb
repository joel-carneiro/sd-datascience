# %%
import pandas as pd

# %% [markdown]
# # Importando dataset

# %%
vendas = pd.read_csv('data/chocolura.csv')
vendas.head()
# Out:
#        mes  vendas
# 0  2017-01     210
# 1  2017-02     185
# 2  2017-03     209
# 3  2017-04     280
# 4  2017-05     211

# %%
vendas['mes'] = pd.to_datetime(vendas['mes'])

# %%
vendas.dtypes
# Out:
# mes       datetime64[ns]
# vendas             int64
# dtype: object

# %%
print('Quantidade de linhas e colunas: ', vendas.shape)
print('Quantidade de dados nulos: ', vendas.isna().sum().sum())
# Out:
# Quantidade de linhas e colunas:  (24, 2)
# Quantidade de dados nulos:  0

# %%
vendas['aumento'] = vendas['vendas'].diff()
vendas['aceleracao'] = vendas['aumento'].diff()

# %%
vendas.head()
# Out:
#          mes  vendas  aumento  aceleracao
# 0 2017-01-01     210      NaN         NaN
# 1 2017-02-01     185    -25.0         NaN
# 2 2017-03-01     209     24.0        49.0
# 3 2017-04-01     280     71.0        47.0
# 4 2017-05-01     211    -69.0      -140.0

# %% [markdown]
# # Plotando gráficos

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
grafico1 = sns.lineplot(x = 'mes', y = 'vendas', data = vendas)
grafico1.figure.set_size_inches(18, 8)

# %%
grafico2 = sns.lineplot(x = 'mes', y = 'aumento', data = vendas)
grafico2.figure.set_size_inches(18, 8)

# %%
grafico3 = sns.lineplot(x = 'mes', y = 'aceleracao', data = vendas)
grafico3.figure.set_size_inches(18, 8)

# %% [markdown]
# # Vendas diárias

# %%
vendas_por_dia = pd.read_csv('data/vendas_por_dia.csv')
vendas_por_dia.head()
# Out:
#           dia  vendas
# 0  2018-10-01      50
# 1  2018-10-02      48
# 2  2018-10-03      56
# 3  2018-10-04      50
# 4  2018-10-05      51

# %%
print('Quantidade de linhas e colunas: ', vendas_por_dia.shape)
print('Quantidade de dados nulos: ', vendas_por_dia.isna().sum().sum())
# Out:
# Quantidade de linhas e colunas:  (61, 2)
# Quantidade de dados nulos:  0

# %%
vendas_por_dia.dtypes
# Out:
# dia       object
# vendas     int64
# dtype: object

# %%
vendas_por_dia['dia'] = pd.to_datetime(vendas_por_dia['dia'])

# %%
vendas_por_dia.dtypes
# Out:
# dia       datetime64[ns]
# vendas             int64
# dtype: object

# %%
vendas_por_dia['aumento'] = vendas_por_dia['vendas'].diff()
vendas_por_dia['aceleracao'] = vendas_por_dia['aumento'].diff()

# %%
vendas_por_dia
# Out:
#           dia  vendas  aumento  aceleracao
# 0  2018-10-01      50      NaN         NaN
# 1  2018-10-02      48     -2.0         NaN
# 2  2018-10-03      56      8.0        10.0
# 3  2018-10-04      50     -6.0       -14.0
# 4  2018-10-05      51      1.0         7.0
# ..        ...     ...      ...         ...
# 56 2018-11-26      54     34.0        31.0
# 57 2018-11-27      60      6.0       -28.0
# 58 2018-11-28      49    -11.0       -17.0
# 59 2018-11-29      50      1.0        12.0
# 60 2018-11-30      52      2.0         1.0
#
# [61 rows x 4 columns]

# %%
grafico1 = sns.lineplot(x = 'dia', y = 'vendas', data = vendas_por_dia)
grafico1.figure.set_size_inches(18, 8)

# %%
grafico2 = sns.lineplot(x = 'dia', y = 'aumento', data = vendas_por_dia)
grafico2.figure.set_size_inches(18, 8)

# %%
grafico3 = sns.lineplot(x = 'dia', y = 'aceleracao', data = vendas_por_dia)
grafico3.figure.set_size_inches(18, 8)

# %%
vendas_por_dia['dia_da_semana'] = vendas_por_dia['dia'].dt.day_name()

# %%
vendas_por_dia
# Out:
#           dia  vendas  aumento  aceleracao dia_da_semana
# 0  2018-10-01      50      NaN         NaN        Monday
# 1  2018-10-02      48     -2.0         NaN       Tuesday
# 2  2018-10-03      56      8.0        10.0     Wednesday
# 3  2018-10-04      50     -6.0       -14.0      Thursday
# 4  2018-10-05      51      1.0         7.0        Friday
# ..        ...     ...      ...         ...           ...
# 56 2018-11-26      54     34.0        31.0        Monday
# 57 2018-11-27      60      6.0       -28.0       Tuesday
# 58 2018-11-28      49    -11.0       -17.0     Wednesday
# 59 2018-11-29      50      1.0        12.0      Thursday
# 60 2018-11-30      52      2.0         1.0        Friday
#
# [61 rows x 5 columns]

# %%
vendas_por_dia['dia_da_semana'].unique()
# Out:
# array(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday',
#        'Sunday'], dtype=object)

# %%
dias_traduzidos = {
    'Monday' : 'Segunda',
    'Tuesday': 'Terça',
    'Wednesday' : 'Quarta',
    'Thursday' : 'Quinta',
    'Friday' : 'Sexta',
    'Saturday' : 'Sábado',
    'Sunday' : 'Domingo'
}

# %%
vendas_por_dia['dia_da_semana'] = vendas_por_dia['dia_da_semana'].map(dias_traduzidos)

# %%
vendas_por_dia
# Out:
#           dia  vendas  aumento  aceleracao dia_da_semana
# 0  2018-10-01      50      NaN         NaN       Segunda
# 1  2018-10-02      48     -2.0         NaN         Terça
# 2  2018-10-03      56      8.0        10.0        Quarta
# 3  2018-10-04      50     -6.0       -14.0        Quinta
# 4  2018-10-05      51      1.0         7.0         Sexta
# ..        ...     ...      ...         ...           ...
# 56 2018-11-26      54     34.0        31.0       Segunda
# 57 2018-11-27      60      6.0       -28.0         Terça
# 58 2018-11-28      49    -11.0       -17.0        Quarta
# 59 2018-11-29      50      1.0        12.0        Quinta
# 60 2018-11-30      52      2.0         1.0         Sexta
#
# [61 rows x 5 columns]

# %%
vendas_agrupadas = vendas_por_dia.groupby('dia_da_semana')['vendas', 'aumento', 'aceleracao'].mean().round(2)
# Out:
# /home/joel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
vendas_agrupadas
# Out:
#                vendas  aumento  aceleracao
# dia_da_semana
# Domingo         18.88     3.00       30.75
# Quarta          53.11     1.44        2.11
# Quinta          51.33    -1.78       -3.22
# Segunda         52.33    33.75       30.75
# Sexta           44.56    -6.78       -5.00
# Sábado          15.88   -27.75      -19.88
# Terça           51.67    -0.67      -34.25

# %%
def plotar(x, y, data):
    grafico = sns.lineplot(x = x, y = y, data = data)
    grafico.figure.set_size_inches(18, 8)
    
    return grafico

# %%
grafico5 = plotar('dia', 'vendas', vendas_por_dia)
