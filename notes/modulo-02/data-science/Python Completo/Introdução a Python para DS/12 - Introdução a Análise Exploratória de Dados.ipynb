# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dates = pd.date_range(start='1/1/2010', end='1/1/2020', freq='d')
profit = np.random.rand(len(datas)) * 1000
rained = np.random.choice([0, 1], len(datas))

# %%
df = pd.DataFrame({
    'data' : dates,
    'lucro' : profit,
    'choveu' : rained
})

# %%
df.head()
# Out:
#         data       lucro  choveu
# 0 2010-01-01   26.490835       1
# 1 2010-01-02  919.519517       1
# 2 2010-01-03  401.436589       0
# 3 2010-01-04  789.251717       1
# 4 2010-01-05  881.769399       1

# %%
df.dtypes
# Out:
# data      datetime64[ns]
# lucro            float64
# choveu             int64
# dtype: object

# %%
plt.plot(df['data'], df['lucro'])
