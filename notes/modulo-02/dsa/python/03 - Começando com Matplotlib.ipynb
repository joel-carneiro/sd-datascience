# %% [markdown]
# # <font color='green'> Breve Visão de Matplotlib </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
x = np.linspace(15, 300, 100)
y = x * 5 + np.random.normal(0, 150, 100)

# %%
plt.scatter(x, y)

# %%
alpha, beta, rvalue, pvalue, std = linregress(x, y)

# %% [markdown]
# <font size=5> $$ f(x) = ax + b$$ </font>

# %%
y_pred = x * alpha + beta

# %%
import pandas as pd

# %%
alpha
# Out:
# 4.7879128837456015

# %%
beta
# Out:
# 25.663417975467496

# %%
plt.scatter(x, y)

plt.xlabel('Tamanho da Casa')
plt.ylabel('Preço da Casa')

plt.plot(x, y_pred, 'orange')
