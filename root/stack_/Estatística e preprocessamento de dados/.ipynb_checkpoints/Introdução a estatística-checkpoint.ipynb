# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/selva86/datasets/master/Auto.csv'

df = pd.read_csv(url)

df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.mean()
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# origin             1.576531
# dtype: float64

# %%
df.median()
# Out:
# mpg               22.75
# cylinders          4.00
# displacement     151.00
# horsepower        93.50
# weight          2803.50
# acceleration      15.50
# year              76.00
# origin             1.00
# dtype: float64

# %%
df.mode()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  13.0        4.0          97.0       150.0  1985.0          14.5  73.0
# 1   NaN        NaN           NaN         NaN  2130.0           NaN   NaN
# 2   NaN        NaN           NaN         NaN     NaN           NaN   NaN
#
#    origin            name
# 0     1.0     amc matador
# 1     NaN      ford pinto
# 2     NaN  toyota corolla

# %%
df['weight'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df['mpg'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
amostragem = df.sample(frac=0.1)
amostragem
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 150  19.0          6         225.0          95    3264          16.0    75
# 118  20.0          4         114.0          91    2582          14.0    73
# 327  44.6          4          91.0          67    1850          13.8    80
# 229  15.5          8         400.0         190    4325          12.2    77
# 111  19.0          4         122.0          85    2310          18.5    73
# 258  18.6          6         225.0         110    3620          18.7    78
# 79   22.0          4         122.0          86    2395          16.0    72
# 112  21.0          6         155.0         107    2472          14.0    73
# 211  13.0          8         350.0         145    4055          12.0    76
# 135  13.0          8         350.0         150    4699          14.5    74
# 73   13.0          8         302.0         140    4294          16.0    72
# ...
