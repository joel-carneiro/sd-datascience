# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd = '/home/joel/Documentos/Dados/kc_house_data.csv'
df = pd.read_csv(pwd)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
x, y = df['sqft_living15'], df['price']

plt.scatter(x, y)

# %%
sns.lmplot(x = 'sqft_living15', y = 'price', data = df)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.predict([[1045]])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_43160/4034958034.py in <module>
# ----> 1 model.predict([[1045]])
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     341
#     342     def _decision_function(self, X):
# --> 343         check_is_fitted(self)
#     344
#     345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
# ...

# %%
model.fit(df[['sqft_living15']], df['price'])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

array1 = np.array([0, 1, 2, 3, 4, 5])
array2 = np.array([0, 2, 4, 6, 8, 10])

model = LinearRegression()
model.fit(array1, array2)
