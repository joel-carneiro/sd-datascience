# %% [markdown]
# # Análise da Qualidade do Ar na Índia de 2018 a 2020
# ## Tendências e Variações Locais
#
# Bem-vindo(a) ao Jupyter Notebook "Análise da Qualidade do Ar na Índia de 2018 a 2020: Tendências e Variações Locais". A qualidade do ar é um tema crucial para a saúde pública, especialmente em países como a Índia, que enfrentam desafios significativos em relação à poluição do ar. Este notebook se concentra em um conjunto de dados abrangente que fornece informações sobre a qualidade do ar na Índia de 2018 a 2020. Com base nesses dados, exploraremos as tendências gerais nos níveis de diferentes poluentes e a variação da poluição do ar entre as cidades indianas. Além disso, utilizaremos gráficos e outras visualizações para ilustrar nossas descobertas de forma clara e concisa. O objetivo final deste notebook é fornecer uma análise detalhada e abrangente da qualidade do ar na Índia, ajudando a identificar as áreas que requerem ações prioritárias e a entender como a poluição do ar afeta a saúde pública na Índia.

# %% [markdown]
# ## Sobre
#
# Este conjunto de dados fornece aos pesquisadores uma visão abrangente da qualidade do ar na Índia de 2018 a 2020. Através dos muitos locais diferentes incluídos, é possível obter insights sobre as tendências nos níveis de óxidos de nitrogênio, dióxido de enxofre, fator de degradação da aviação, monóxido de carbono e Material Particulado Suspenso (SPM). Além disso, este conjunto de dados poderoso destaca a variação nos níveis de poluição do ar localizada por cidade para fornecer uma perspectiva única sobre os níveis de poluição do ar locais. Com pontos de dados que variam de megacidades populosas a vilas rurais, este recurso capacitará qualquer pesquisador interessado em estudar a qualidade do ar da Índia nos últimos anos.

# %% [markdown]
# # 1 - Introdução

# %% [markdown]
# ## 1.1 - Importando módulos

# %%
import pandas as pd

# %% [markdown]
# ## 1.1 - Coleta de Dados

# %%
file = '/home/jdspy/Documentos/projects/india_dataset/Parks_and_the_pandemic_PUD_data.csv'
dataset = pd.read_csv(file)

# %%
dataset
# Out:
#                                             Date   Status  1/1/2017  1/2/2017  \
# 0                  Allamuchy Mountain State Park   Closed         3         0
# 1                               Apshawa Preserve   Closed         0         0
# 2             Assunpink Wildlife Management Area     Open         0         0
# 3                              Baldpate Mountain   Closed         0         0
# 4                            Bear Creek Preserve     Open         0         0
# ..                                           ...      ...       ...       ...
# 93  Washington Valley Park aka Chimney Rock Park   Closed         1         0
# 94                          Wawayanda State Park   Closed         8         3
# 95                       Wells Mills County Park   Closed         1         1
# 96                                 Wildcat Ridge   Closed         3         1
# 97                                Wood Dale Park  Unknown         0         0
#
# ...

# %% [markdown]
# ## 2 - Análise de Dados

# %%
dataset['Date'].unique()
# Out:
# array(['Allamuchy Mountain State Park', 'Apshawa Preserve',
#        'Assunpink Wildlife Management Area', 'Baldpate Mountain',
#        'Bear Creek Preserve', 'Big Brook Park',
#        'Black River Wildlife Management Area', 'Branch Brook Park',
#        'Briant Park', 'Brookdale Park', 'Bulls Island State Park',
#        'Campgaw Mountain Reservation', 'Cheesequake State Park',
#        'Chubb Park', 'Clayton Park', 'Colonial Park', 'Columbia Trail',
#        'Cooper River Park', 'D&R Canal State Park',
#        'Davidson Mill Pond County Park', 'Dismal Swamp State Park',
#        'Donaldson County Park', 'Duke Farms', 'Duke Island Park',
#        'Eagle Rock Reservation', 'Echo Hill Park', 'Echo Lake',
#        'Ernest L. Oros Wildlife Refuge',
#        "Fisherman's Cove Conservation Area", 'Frelinghuysen Arboretum',
#        'Garret Mountain Reservation', 'Glenfield Park',
#        'Goffle Brook Park', 'Grace Lord Park',
# ...
